# %% [markdown]
# <a href="https://colab.research.google.com/github/poorna2352/BASIC-ML/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EDA ON BANK NOTE AUTHENTICATION**

# %% [markdown]
# **INTRODUCTION**

# %% [markdown]
# In this notebook , I have done the Exexploratory Data Analysis of the bank note authentication and tried to gain useful insights from the data.the feautures present in the data set are :
#
# * variance
# * skewness
# * curtosis
# * entropy

# %% [markdown]
# Before diving into the data set, we have to know the main aim of EDA
#
# Exploratory Data Analysis (EDA) is the data exploration technique to understand various aspects of data.

# %% [markdown]
# Steps involved in EDA are :
# * Understanding the data
# * cleaning the data
# * Analysis of relationship between variables.

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# **PRELIMINARY DATA ANALYSIS**

# %% [markdown]
# To start off,we read our dataset and generate a simple preview and statistics of our data.

# %% [markdown]
# **LOADING DATA**

# %%
data=pd.read_csv("BankNote_Authentication.csv")
data
# Out:
#       variance  skewness  curtosis  entropy  class
# 0      3.62160   8.66610   -2.8073 -0.44699      0
# 1      4.54590   8.16740   -2.4586 -1.46210      0
# 2      3.86600  -2.63830    1.9242  0.10645      0
# 3      3.45660   9.52280   -4.0112 -3.59440      0
# 4      0.32924  -4.45520    4.5718 -0.98880      0
# ...        ...       ...       ...      ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1
#
# [1372 rows x 5 columns]

# %% [markdown]
# The output shows that we have 1372 entries with 5 columns in our dataset.

# %% [markdown]
# **Understanding the Data**

# %%
data.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %% [markdown]
# The output shows the first five rows of our dataset.

# %%
data.shape
# Out:
# (1372, 5)

# %% [markdown]
# shape member returns the dimensions of our dataset

# %%
data.columns
# Out:
# Index(['variance', 'skewness', 'curtosis', 'entropy', 'class'], dtype='object')

# %% [markdown]
# this returns the names of columns in our dataset

# %%
data.describe().transpose()
# Out:
#            count      mean       std  ...      50%       75%      max
# variance  1372.0  0.433735  2.842763  ...  0.49618  2.821475   6.8248
# skewness  1372.0  1.922353  5.869047  ...  2.31965  6.814625  12.9516
# curtosis  1372.0  1.397627  4.310030  ...  0.61663  3.179250  17.9274
# entropy   1372.0 -1.191657  2.101013  ... -0.58665  0.394810   2.4495
# class     1372.0  0.444606  0.497103  ...  0.00000  1.000000   1.0000
#
# [5 rows x 8 columns]

# %% [markdown]
# This method generates a high-level summary of attributes over each column of the dataset. More probably it provides the statistical insights of the dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   variance  1372 non-null   float64
#  1   skewness  1372 non-null   float64
#  2   curtosis  1372 non-null   float64
#  3   entropy   1372 non-null   float64
#  4   class     1372 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 53.7 KB

# %% [markdown]
# Here is the more information of our dataset choosen.from the above observation it is clear that all the columns of our dataset are free from null values.

# %%
data["class"].value_counts()
# Out:
# 0    762
# 1    610
# Name: class, dtype: int64

# %%
x=data.iloc[ : , :-1]
x.head()
# Out:
#    variance  skewness  curtosis  entropy
# 0   3.62160    8.6661   -2.8073 -0.44699
# 1   4.54590    8.1674   -2.4586 -1.46210
# 2   3.86600   -2.6383    1.9242  0.10645
# 3   3.45660    9.5228   -4.0112 -3.59440
# 4   0.32924   -4.4552    4.5718 -0.98880

# %%
df.isnull().sum()
# Out:
# variance    0
# skewness    0
# curtosis    0
# entropy     0
# class       0
# dtype: int64

# %% [markdown]
# it is clear that there are no missing values in each column present in our dataset.

# %% [markdown]
# **DATA VISUALIZATION**

# %% [markdown]
# **COUNT PLOT**

# %%
plot=sns.countplot(x="class",data=data)

# %% [markdown]
# from this visualization we can observe that our data set is a balanced dataset.
# in this data set
#
# 0 represents genuine notes
#
# 1 represents fake notes
#
# from the above plot it is clear that genuine notes are more in number than fake notes.

# %% [markdown]
# **CORRELATION BETWEEN VARIABLES**

# %%
data.corr()
# Out:
#           variance  skewness  curtosis   entropy     class
# variance  1.000000  0.264026 -0.380850  0.276817 -0.724843
# skewness  0.264026  1.000000 -0.786895 -0.526321 -0.444688
# curtosis -0.380850 -0.786895  1.000000  0.318841  0.155883
# entropy   0.276817 -0.526321  0.318841  1.000000 -0.023424
# class    -0.724843 -0.444688  0.155883 -0.023424  1.000000

# %% [markdown]
# **visualizing the correlation using a HEAT MAP**

# %%
fig=plt.figure(figsize=(15,15))
sns.heatmap(data.corr(),cmap="Reds",annot=True);

# %% [markdown]
# This correlation diagram shows that the class column does not have much correlation with other column of the dataset

# %% [markdown]
# **PAIR PLOT**

# %%
sns.pairplot(data= data,hue= "class")

# %% [markdown]
# pair plot is showing the bivariate relation between each pair of feautures.

# %% [markdown]
# **SCATTER PLOT**

# %%
plot=sns.scatterplot(x="skewness",y="variance",hue="class",data=data)

# %% [markdown]
# From the above visualization, we can observe that genuine notes have more skewness(i.e, symmetric) and more variance than fake notes.

# %% [markdown]
# **BOX PLOT**

# %%
fig,axs= plt.subplots(figsize=(8,6))
plot=sns.boxplot(x="class",y="variance",data=data)

# %% [markdown]
# From the above box plot it is clear that the notes having more variance are genuine notes and less variance are fake notes.

# %% [markdown]
# **VIOLIN PLOT**

# %%
sns.violinplot(x="class",y="curtosis",data=data,size=5)

# %% [markdown]
# From the above plot we can observe that fake notes have high curtosis compared to genuine notes.we can also observe that fake notes have some duplicate values or outliers.

# %% [markdown]
# **JOINT PLOT**

# %%
sns.jointplot(x="entropy",y="variance",data=data,height=5)
plt.show()

# %% [markdown]
# We can also use the seaborn library to make similar plot.A seaborn jointplot shows bivariate scatterplots and univariate histograms in the same figure.

# %% [markdown]
# **HIST PLOT**

# %%
data.hist(edgecolor="black",bins=23,figsize=(15,15))
plt.show()

# %% [markdown]
# **CONCLUSION**

# %% [markdown]
# - From all the above observations we can clearly undrestand that our data set is a balanced dataset.it contains genuine and fake notes almost in equal number(not exactly equal but approximately).
#
# - A strong correlation is present between variance and entropy.
#
# - some fake notes are easier to distinguish but some are hard to distinguish because some fake notes have the exactly same feautures of genuine notes
#
# - After performing EDA on BankNote Authentication we can conclude that notes having high variance,skewness,entropy and low curtosis are genuine notes and notes that are having low variance,skewness,entropy and high curtosis are fake notes.
