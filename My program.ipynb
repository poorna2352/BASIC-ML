# %%
1)maximum of three numbers

# %%
a=7
b=5
if a>b:
      print("a is maximum") 
else:
     print("b is maximum")
# Out:
# a is maximum

# %%
Explanation:
1)give the input as a&b and assign some integer values
2)check whether a Or b is maximum by using if else conditions
3) print the maximum number as output

# %%
2)even or odd

# %%
n=6
if (n%2==0):
    print("even") 
else:
    print("odd")
# Out:
# even

# %%
Explanation:
1.Give some number as input
2)Check whether the given number is (n%2==0) if it's equal to zero then print even, else print odd. 
3)By using if else conditions we can assumpt whether the given number is even or odd.

# %%
3) factorial of number

# %%
n=10
f=1
for i in range(1,n+1):
         f=f*i
print(f)
# Out:
# 3628800

# %%
Explanation:
1)read n value
2)intialize f=1
3)fix the range as (1, n+1) and do
       f=f*1
4) print the result(Print(f)).
